# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
! pip install rinohtype
# Out:
# ...
#      |████████████████████████████████| 604kB 3.4MB/s
# ...
#      |████████████████████████████████| 327kB 9.7MB/s
# ...
#      |████████████████████████████████| 1.7MB 17.0MB/s
# ...
#      |████████████████████████████████| 532kB 29.4MB/s
# ...
#      |████████████████████████████████| 245kB 32.5MB/s
# ...
#      |████████████████████████████████| 51kB 5.9MB/s
# ...

# %%
! python --version
# Out:
# Python 3.6.9

# %%
! pip install sphinx

# %%
import os

os.chdir('/content/drive/My Drive/torchOnVideo')

# %%
! ls
# Out:
# build  _build  docs  __init__.py  Makefile  source  Video_Classification

# %%
! mkdir docs
! cd docs
# Out:
# mkdir: cannot create directory ‘docs’: File exists

# %%
! sphinx-quickstart
# Out:
# Welcome to the Sphinx 1.4.8 quickstart utility.
#
# Please enter values for the following settings (just press Enter to
# accept a default value, if one is given in brackets).
#
# Enter the root path for documentation.
# > Root path for the documentation [.]:
#
# Error: an existing conf.py has been found in the selected root path.
# sphinx-quickstart will not overwrite existing Sphinx projects.
#
# > Please enter a new root path (or just Enter to exit):

# %%
ls
# Out:
# build/  _build/  docs/  __init__.py  Makefile  source/  Video_Classification/

# %%
pip install docutils==0.12

# %%
! make html
# Out:
# Running Sphinx v1.4.8
# loading pickled environment... not yet created
# building [mo]: targets for 0 po files that are out of date
# building [html]: targets for 1 source files that are out of date
# updating environment: 1 added, 0 changed, 0 removed
# reading sources... [100%] index
# /content/drive/My Drive/torchOnVideo/source/index.rst:14: WARNING: Title underline too short.
#
# IClassifyBetter main
# ...
# /content/drive/My Drive/torchOnVideo/source/index.rst:14: WARNING: Title underline too short.
#
# IClassifyBetter main
# ...
# looking for now-outdated files... none found
# pickling environment... done
# checking consistency... done
# preparing documents... done
# writing output... [100%] index
# generating indices... genindex
# writing additional pages... search
# copying static files... done
# copying extra files... done
# dumping search index in English (code: en) ... done
# dumping object inventory... done
# build succeeded, 2 warnings.
#
# ...

# %%
! sphinx --version
# Out:
# /bin/bash: sphinx: command not found

# %%
! make html
# Out:
# Running Sphinx v1.4.8
# loading pickled environment... done
# building [mo]: targets for 0 po files that are out of date
# building [html]: targets for 1 source files that are out of date
# updating environment: 0 added, 1 changed, 0 removed
# reading sources... [100%] index
# /content/drive/My Drive/torchOnVideo/source/index.rst:15: WARNING: Title underline too short.
#
# IClassifyBetter Train
# ...
# /content/drive/My Drive/torchOnVideo/source/index.rst:15: WARNING: Title underline too short.
#
# IClassifyBetter Train
# ...
# /content/drive/My Drive/torchOnVideo/source/index.rst:16: WARNING: autodoc: failed to import module 'Video_Classification.IClassifyBetter_train_attention'; the following exception was raised:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/sphinx/ext/autodoc.py", line 519, in import_object
#     __import__(self.modname)
# ModuleNotFoundError: No module named 'Video_Classification'
# ...

# %%
! make clean
# Out:
# Removing everything under 'build'...

# %%
! make html
# Out:
# Running Sphinx v1.4.8
# making output directory...
# loading pickled environment... not yet created
# building [mo]: targets for 0 po files that are out of date
# building [html]: targets for 1 source files that are out of date
# updating environment: 1 added, 0 changed, 0 removed
# reading sources... [100%] index
# /content/drive/My Drive/torchOnVideo/source/index.rst:15: WARNING: Title underline too short.
#
# IClassifyBetter Train
# ...
# /content/drive/My Drive/torchOnVideo/source/index.rst:15: WARNING: Title underline too short.
#
# IClassifyBetter Train
# ...
# /content/drive/My Drive/torchOnVideo/source/index.rst:16: WARNING: autodoc: failed to import module 'Video_Classification.IClassifyBetter_train_attention'; the following exception was raised:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/sphinx/ext/autodoc.py", line 519, in import_object
#     __import__(self.modname)
# ModuleNotFoundError: No module named 'Video_Classification'
# ...
